# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
from tensorflow import keras
from kerastuner.tuners import RandomSearch
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Read the CSV file into a DataFrame
df = pd.read_csv('Updated_FinalFilteredCombined.csv')

# Display the first 5 rows
print(df.head())

# Print the column names and their data types
print(df.info())
# Out:
#    index  AADT_VN  BEGIN_POIN  COUNTY_COD  END_POINT  IRI_VN  IS_IMPROVED  \
# 0      0    44290         5.3          97        5.4      44            0
# 1      1    44750         5.3          97        5.4      48            0
# 2      2    45760         5.3          97        5.4      80            0
# 3      3    48670         5.3          97        5.4      43            1
# 4      4    49080         5.3          97        5.4      39            1
#
#        ROUTE_ID  SPEED_LIMI  THROUGH_LA  YEAR_RECOR  curval  \
# 0  IN0000100000        60.0           4        2013     263
# 1  IN0000100000        60.0           4        2014     268
# 2  IN0000100000        60.0           4        2015     192
# 3  IN0000100000        70.0           4        2016     176
# 4  IN0000100000        70.0           4        2017     205
#
#                                       geometry_paths  tmiles  tons  value
# 0  [[[-88.31770505199995, 30.49976574300007], [-8...      15   716    270
# 1  [[[-88.31770505199995, 30.49976574300007], [-8...      16   750    286
# 2  [[[-88.31770505199995, 30.49976574300007], [-8...      17   778    292
# 3  [[[-88.31770505199995, 30.49976574300007], [-8...      17   783    311
# 4  [[[-88.12412879499999, 30.698415469000054], [-...      17   771    314
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7119 entries, 0 to 7118
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           7119 non-null   int64
#  1   AADT_VN         7119 non-null   int64
#  2   BEGIN_POIN      7119 non-null   float64
#  3   COUNTY_COD      7119 non-null   int64
#  4   END_POINT       7119 non-null   float64
#  5   IRI_VN          7119 non-null   int64
#  6   IS_IMPROVED     7119 non-null   int64
#  7   ROUTE_ID        7119 non-null   object
#  8   SPEED_LIMI      7119 non-null   float64
#  9   THROUGH_LA      7119 non-null   int64
#  10  YEAR_RECOR      7119 non-null   int64
#  11  curval          7119 non-null   int64
#  12  geometry_paths  7119 non-null   object
#  13  tmiles          7119 non-null   int64
#  14  tons            7119 non-null   int64
#  15  value           7119 non-null   int64
# dtypes: float64(3), int64(11), object(2)
# memory usage: 890.0+ KB
# None

# %%
print(df.columns)
# Out:
# Index(['index', 'AADT_VN', 'BEGIN_POIN', 'COUNTY_COD', 'END_POINT', 'IRI_VN',
#        'IS_IMPROVED', 'ROUTE_ID', 'SPEED_LIMI', 'THROUGH_LA', 'YEAR_RECOR',
#        'curval', 'geometry_paths', 'tmiles', 'tons', 'value'],
#       dtype='object')

# %%
df_2022 = df[df['YEAR_RECOR'] == 2022]

# %%
df = df[df['YEAR_RECOR'] != 2022]

# %%
df.index = range(1, len(df) + 1)
df.reset_index(inplace=True, names=['new_index'])  # Add 'new_index' as a column

# Method 2: Creating a new column directly
df['new_index'] = range(1, len(df) + 1)

# If you want 'index' instead of 'new_index'
df.rename(columns={'new_index': 'index'}, inplace=True)

# %%
df['index'] = df['index'] + 1

# %%
train_months = df['index']

# %%
cols = ['AADT_VN', 'BEGIN_POIN', 'COUNTY_COD', 'END_POINT', 'IS_IMPROVED', 'SPEED_LIMI', 'THROUGH_LA', 'YEAR_RECOR', 'curval', 'tmiles', 'tons', 'value']
target_col = 'IRI_VN'

# %%
df_for_training = df[cols + [target_col]]

# %%
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []

# %%
n_future = 1
n_past = 9

# %%
for i in range(n_past, len(df_for_training_scaled) - n_future + 1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:len(cols)])  # Only features
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, len(cols)])

# %%
trainX, trainY = np.array(trainX), np.array(trainY)

# %%
print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))
# Out:
# trainX shape == (6319, 9, 12).
# trainY shape == (6319, 1).

# %%
print(trainY)
# Out:
# [[-0.50681722]
#  [-0.11282636]
#  [-0.5247259 ]
#  ...
#  [ 1.21241565]
#  [ 5.56422385]
#  [ 1.40941108]]

# %%
X_train, X_test, y_train, y_test = train_test_split(trainX, trainY, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.regularizers import l2, l1, l1_l2

model = Sequential()
model.add(LSTM(96, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, kernel_regularizer= l1(0.000001)))
model.add(LSTM(64, activation='relu', return_sequences=True, kernel_regularizer= l1(0.000001)))
model.add(LSTM(32, activation='relu', return_sequences=False, kernel_regularizer= l1(0.000001)))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1], kernel_regularizer= l1(0.000001)))
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mse')
model.summary()
# Out:
# Model: "sequential_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_77 (LSTM)                  │ (None, 9, 96)          │        41,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_78 (LSTM)                  │ (None, 9, 64)          │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_79 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,521 (373.13 KB)
#  Trainable params: 95,521 (373.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
# Out:
# Epoch 1/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 76s 18ms/step - loss: 0.9757 - val_loss: 0.9207
# Epoch 2/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.7133 - val_loss: 0.8170
# Epoch 3/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.6465 - val_loss: 0.7431
# Epoch 4/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.6404 - val_loss: 0.7017
# Epoch 5/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.5725 - val_loss: 0.7253
# Epoch 6/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.6039 - val_loss: 0.7101
# Epoch 7/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5918 - val_loss: 0.6583
# Epoch 8/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.5639 - val_loss: 0.6713
# Epoch 9/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5667 - val_loss: 0.6598
# Epoch 10/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5508 - val_loss: 0.6567
# Epoch 11/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5627 - val_loss: 0.6388
# Epoch 12/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5012 - val_loss: 0.6225
# Epoch 13/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.4618 - val_loss: 0.6151
# Epoch 14/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.5338 - val_loss: 0.6248
# Epoch 15/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.5157 - val_loss: 0.6061
# Epoch 16/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4591 - val_loss: 0.5995
# Epoch 17/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.4798 - val_loss: 0.5770
# Epoch 18/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4365 - val_loss: 0.5613
# Epoch 19/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.4767 - val_loss: 0.5678
# Epoch 20/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.5165 - val_loss: 0.5599
# Epoch 21/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.4499 - val_loss: 0.5595
# Epoch 22/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4588 - val_loss: 0.5705
# Epoch 23/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4516 - val_loss: 0.5762
# Epoch 24/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4484 - val_loss: 0.5496
# Epoch 25/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4295 - val_loss: 0.6014
# Epoch 26/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4448 - val_loss: 0.5263
# Epoch 27/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.4248 - val_loss: 0.5329
# Epoch 28/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4729 - val_loss: 0.5150
# Epoch 29/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4271 - val_loss: 0.5495
# Epoch 30/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.4140 - val_loss: 0.5248
# Epoch 31/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3772 - val_loss: 0.5235
# Epoch 32/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3908 - val_loss: 0.5222
# Epoch 33/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3979 - val_loss: 0.5227
# Epoch 34/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.4734 - val_loss: 0.5274
# Epoch 35/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3813 - val_loss: 0.5375
# Epoch 36/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3995 - val_loss: 0.5159
# Epoch 37/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3999 - val_loss: 0.5138
# Epoch 38/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.4008 - val_loss: 0.5671
# Epoch 39/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.4089 - val_loss: 0.5411
# Epoch 40/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3754 - val_loss: 0.5288
# Epoch 41/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3960 - val_loss: 0.5247
# Epoch 42/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.3783 - val_loss: 0.5294
# Epoch 43/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3983 - val_loss: 0.5147
# Epoch 44/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3833 - val_loss: 0.5060
# Epoch 45/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3682 - val_loss: 0.5102
# Epoch 46/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3876 - val_loss: 0.4884
# Epoch 47/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3582 - val_loss: 0.5269
# Epoch 48/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3830 - val_loss: 0.4914
# Epoch 49/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3489 - val_loss: 0.4969
# Epoch 50/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.3618 - val_loss: 0.5449
# Epoch 51/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3879 - val_loss: 0.4997
# Epoch 52/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.3410 - val_loss: 0.4963
# Epoch 53/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.3750 - val_loss: 0.5413
# Epoch 54/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.4087 - val_loss: 0.4930
# Epoch 55/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3575 - val_loss: 0.4902
# Epoch 56/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.3461 - val_loss: 0.5024
# Epoch 57/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3710 - val_loss: 0.5065
# Epoch 58/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3111 - val_loss: 0.4942
# Epoch 59/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3572 - val_loss: 0.4896
# Epoch 60/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3276 - val_loss: 0.5014
# Epoch 61/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3555 - val_loss: 0.5149
# Epoch 62/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3222 - val_loss: 0.4936
# Epoch 63/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3660 - val_loss: 0.5058
# Epoch 64/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3254 - val_loss: 0.5076
# Epoch 65/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3221 - val_loss: 0.4955
# Epoch 66/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3021 - val_loss: 0.5092
# Epoch 67/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3511 - val_loss: 0.4855
# Epoch 68/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3487 - val_loss: 0.5137
# Epoch 69/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3263 - val_loss: 0.5218
# Epoch 70/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3224 - val_loss: 0.5025
# Epoch 71/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3325 - val_loss: 0.4854
# Epoch 72/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3173 - val_loss: 0.5068
# Epoch 73/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3701 - val_loss: 0.5632
# Epoch 74/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2924 - val_loss: 0.4746
# Epoch 75/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3358 - val_loss: 0.4864
# Epoch 76/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3403 - val_loss: 0.4882
# Epoch 77/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3111 - val_loss: 0.5028
# Epoch 78/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3173 - val_loss: 0.4953
# Epoch 79/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2975 - val_loss: 0.5142
# Epoch 80/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3014 - val_loss: 0.5131
# Epoch 81/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3046 - val_loss: 0.5253
# Epoch 82/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3033 - val_loss: 0.5071
# Epoch 83/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2712 - val_loss: 0.5141
# Epoch 84/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3273 - val_loss: 0.5069
# Epoch 85/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3035 - val_loss: 0.4942
# Epoch 86/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2885 - val_loss: 0.5144
# Epoch 87/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3033 - val_loss: 0.5084
# Epoch 88/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2861 - val_loss: 0.5069
# Epoch 89/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3043 - val_loss: 0.4975
# Epoch 90/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2970 - val_loss: 0.5108
# Epoch 91/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3208 - val_loss: 0.4890
# Epoch 92/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3063 - val_loss: 0.4996
# Epoch 93/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2658 - val_loss: 0.5410
# Epoch 94/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2922 - val_loss: 0.5534
# Epoch 95/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3148 - val_loss: 0.4886
# Epoch 96/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2881 - val_loss: 0.4844
# Epoch 97/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2793 - val_loss: 0.5225
# Epoch 98/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2612 - val_loss: 0.4999
# Epoch 99/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.3038 - val_loss: 0.5082
# Epoch 100/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2942 - val_loss: 0.5317
# Epoch 101/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2869 - val_loss: 0.5065
# Epoch 102/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2867 - val_loss: 0.5302
# Epoch 103/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2684 - val_loss: 0.5120
# Epoch 104/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2807 - val_loss: 0.4903
# Epoch 105/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2866 - val_loss: 0.5137
# Epoch 106/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3079 - val_loss: 0.4790
# Epoch 107/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.2812 - val_loss: 0.5879
# Epoch 108/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2718 - val_loss: 0.5400
# Epoch 109/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2742 - val_loss: 0.5478
# Epoch 110/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.3083 - val_loss: 0.5276
# Epoch 111/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2774 - val_loss: 0.5044
# Epoch 112/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.3027 - val_loss: 0.4940
# Epoch 113/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2640 - val_loss: 0.5174
# Epoch 114/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.2703 - val_loss: 0.4872
# Epoch 115/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2789 - val_loss: 0.4961
# Epoch 116/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2748 - val_loss: 0.5884
# Epoch 117/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2433 - val_loss: 0.5622
# Epoch 118/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2882 - val_loss: 0.5331
# Epoch 119/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3007 - val_loss: 0.5365
# Epoch 120/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2843 - val_loss: 0.5113
# Epoch 121/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2589 - val_loss: 0.4968
# Epoch 122/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2572 - val_loss: 0.5411
# Epoch 123/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2929 - val_loss: 0.5315
# Epoch 124/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2626 - val_loss: 0.5579
# Epoch 125/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2734 - val_loss: 0.5241
# Epoch 126/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2929 - val_loss: 0.5290
# Epoch 127/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2871 - val_loss: 0.5029
# Epoch 128/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2803 - val_loss: 0.5066
# Epoch 129/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2268 - val_loss: 0.5059
# Epoch 130/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2441 - val_loss: 0.5003
# Epoch 131/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2428 - val_loss: 0.4810
# Epoch 132/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2720 - val_loss: 0.5104
# Epoch 133/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2874 - val_loss: 0.5762
# Epoch 134/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2550 - val_loss: 0.5083
# Epoch 135/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2796 - val_loss: 0.5074
# Epoch 136/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2496 - val_loss: 0.4978
# Epoch 137/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2767 - val_loss: 0.5409
# Epoch 138/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2630 - val_loss: 0.4646
# Epoch 139/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2623 - val_loss: 0.5544
# Epoch 140/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2426 - val_loss: 0.5080
# Epoch 141/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2603 - val_loss: 0.5569
# Epoch 142/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2494 - val_loss: 0.5392
# Epoch 143/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2458 - val_loss: 0.5114
# Epoch 144/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2523 - val_loss: 0.5013
# Epoch 145/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2571 - val_loss: 0.5090
# Epoch 146/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2404 - val_loss: 0.5184
# Epoch 147/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2508 - val_loss: 0.5400
# Epoch 148/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2499 - val_loss: 0.4955
# Epoch 149/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2460 - val_loss: 0.4975
# Epoch 150/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2393 - val_loss: 0.5562
# Epoch 151/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2154 - val_loss: 0.5383
# Epoch 152/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2165 - val_loss: 0.5276
# Epoch 153/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2636 - val_loss: 0.5094
# Epoch 154/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2455 - val_loss: 0.5574
# Epoch 155/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2423 - val_loss: 0.5662
# Epoch 156/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2270 - val_loss: 0.5606
# Epoch 157/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2279 - val_loss: 0.5254
# Epoch 158/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2368 - val_loss: 0.5203
# Epoch 159/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2211 - val_loss: 0.5176
# Epoch 160/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2206 - val_loss: 0.5685
# Epoch 161/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2449 - val_loss: 0.5106
# Epoch 162/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2267 - val_loss: 0.5689
# Epoch 163/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2530 - val_loss: 0.5314
# Epoch 164/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2190 - val_loss: 0.4939
# Epoch 165/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2212 - val_loss: 0.5711
# Epoch 166/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2279 - val_loss: 0.5156
# Epoch 167/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2560 - val_loss: 0.5445
# Epoch 168/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2405 - val_loss: 0.5375
# Epoch 169/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2297 - val_loss: 0.5038
# Epoch 170/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2245 - val_loss: 0.5961
# Epoch 171/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2302 - val_loss: 0.5562
# Epoch 172/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2164 - val_loss: 0.5058
# Epoch 173/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2072 - val_loss: 0.5397
# Epoch 174/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2234 - val_loss: 0.4982
# Epoch 175/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2345 - val_loss: 0.5449
# Epoch 176/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2455 - val_loss: 0.5008
# Epoch 177/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2182 - val_loss: 0.5280
# Epoch 178/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2174 - val_loss: 0.5454
# Epoch 179/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2216 - val_loss: 0.5481
# Epoch 180/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2246 - val_loss: 0.4949
# Epoch 181/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2370 - val_loss: 0.5087
# Epoch 182/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2352 - val_loss: 0.4933
# Epoch 183/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2402 - val_loss: 0.5822
# Epoch 184/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2081 - val_loss: 0.5796
# Epoch 185/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2100 - val_loss: 0.5294
# Epoch 186/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2300 - val_loss: 0.4984
# Epoch 187/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.2212 - val_loss: 0.4833
# Epoch 188/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1983 - val_loss: 0.5475
# Epoch 189/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2151 - val_loss: 0.5982
# Epoch 190/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2200 - val_loss: 0.5436
# Epoch 191/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2504 - val_loss: 0.5146
# Epoch 192/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1943 - val_loss: 0.5800
# Epoch 193/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.2201 - val_loss: 0.5057
# Epoch 194/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.2023 - val_loss: 0.5200
# Epoch 195/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1998 - val_loss: 0.5453
# Epoch 196/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2184 - val_loss: 0.5134
# Epoch 197/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2020 - val_loss: 0.5555
# Epoch 198/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2018 - val_loss: 0.5561
# Epoch 199/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.2171 - val_loss: 0.5719
# Epoch 200/200
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.2152 - val_loss: 0.5323

# %%
y_pred = model.predict(X_test)

y_pred_original = np.zeros((y_pred.shape[0], df_for_training.shape[1])) # Dummy array with correct number of columns
y_pred_original[:, -1] = y_pred[:, 0]  # Place predictions in the last column
y_pred_original = scaler.inverse_transform(y_pred_original)[:, -1]
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step

# %%
# Create a dummy array for y_test as well
y_test_original = np.zeros((y_test.shape[0], df_for_training.shape[1]))
y_test_original[:, -1] = y_test[:, 0]
y_test_original = scaler.inverse_transform(y_test_original)[:, -1]

# %%
print(y_pred_original)
print(y_test_original)
# Out:
# [ 51.09524854  37.64978945  62.49067379 ...  44.71081285  59.51830717
#  172.35045497]
# [ 62.  37.  54. ...  44.  69. 113.]

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_original, label='Actual')
plt.plot(y_pred_original, label='Predicted')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Actual vs. Predicted')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test_original, y_pred_original)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1065.8973617876109

# %%
from sklearn.metrics import r2_score

# Calculate R² for the training set
y_train_pred = model.predict(X_train)

y_train_pred_original = np.zeros((y_train_pred.shape[0], df_for_training.shape[1]))
y_train_pred_original[:, -1] = y_train_pred[:, 0]
y_train_pred_original = scaler.inverse_transform(y_train_pred_original)[:, -1]

y_train_original = np.zeros((y_train.shape[0], df_for_training.shape[1]))
y_train_original[:, -1] = y_train[:, 0]
y_train_original = scaler.inverse_transform(y_train_original)[:, -1]

r2_train = r2_score(y_train_original, y_train_pred_original)
print(f'R² score for training set: {r2_train}')

# Calculate R² for the test set
y_test_pred = model.predict(X_test)

y_test_pred_original = np.zeros((y_test_pred.shape[0], df_for_training.shape[1]))
y_test_pred_original[:, -1] = y_test_pred[:, 0]
y_test_pred_original = scaler.inverse_transform(y_test_pred_original)[:, -1]

y_test_original = np.zeros((y_test.shape[0], df_for_training.shape[1]))
y_test_original[:, -1] = y_test[:, 0]
y_test_original = scaler.inverse_transform(y_test_original)[:, -1]

r2_test = r2_score(y_test_original, y_test_pred_original)
print(f'R² score for test set: {r2_test}')
# Out:
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# R² score for training set: 0.7833380565795022
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# R² score for test set: 0.6578433543702364

# %%
def build_model(hp):
    model_hp = Sequential()
    model_hp.add(LSTM(hp.Int('units_lstm1', min_value=64, max_value=512, step=64),
                   return_sequences=True,
                   input_shape=(X_train.shape[1], X_train.shape[2]),
                   activation='relu'))

    model_hp.add(LSTM(hp.Int('units_lstm2', min_value=32, max_value=512, step=32),
                   return_sequences=False,
                   activation='relu'))
    model_hp.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=1.0, step=0.1)))
    model_hp.add(Dense(trainY.shape[1]))

    model_hp.compile(optimizer=keras.optimizers.Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')),
                  loss='mse')
    return model_hp

# %%
tuner_hp = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=20,      
    executions_per_trial=3, 
    directory='tuning_dir',
    project_name='hp_1'
)

# %%
tuner_hp.search_space_summary()

# %%
tuner_hp.search(X_train, y_train, epochs=60, batch_size=32, validation_split=0.2, verbose=1)

# %%
tuner_hp.results_summary()

# %%
best_model = tuner_hp.get_best_models(num_models=1)[0]
print(best_model)

# %%
y_train_pred_hp = best_model.predict(X_train)
y_test_pred_hp = best_model.predict(X_test)

# %%
# Inverse transform the predictions (assuming 'scaler' is your StandardScaler)
y_train_pred_hp = np.zeros((y_train_pred_hp.shape[0], df_for_training.shape[1]))
y_train_pred_hp[:, -1] = y_train_pred_hp[:, 0]
y_train_pred_hp = scaler.inverse_transform(y_train_pred_hp)[:, -1]

y_train_original = np.zeros((y_train.shape[0], df_for_training.shape[1]))
y_train_original[:, -1] = y_train[:, 0]
y_train_original = scaler.inverse_transform(y_train_original)[:, -1]

y_test_pred_hp = np.zeros((y_test_pred_hp.shape[0], df_for_training.shape[1]))
y_test_pred_hp[:, -1] = y_test_pred_hp[:, 0]
y_test_pred_hp = scaler.inverse_transform(y_test_pred_hp)[:, -1]

y_test_original = np.zeros((y_test.shape[0], df_for_training.shape[1]))
y_test_original[:, -1] = y_test[:, 0]
y_test_original = scaler.inverse_transform(y_test_original)[:, -1]

# %%
from sklearn.metrics import r2_score


r2_train = r2_score(y_train_original, y_train_pred_hp)
r2_test = r2_score(y_test_original, y_test_pred_hp)

print(f'Best Model Training R²: {r2_train}')
print(f'Best Model Test R²: {r2_test}')
